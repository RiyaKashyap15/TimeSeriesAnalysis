# %% [markdown]
# ## Time Series EDA

# %%
## Install Pandas Data Reader
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df_tesla=pdr.get_data_yahoo('TWTR')

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.tail()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2022-06-09  40.540001  39.529999  40.250000  39.529999   7970300  39.529999
# 2022-06-10  39.630001  38.889999  39.520000  38.980000  10527700  38.980000
# 2022-06-13  38.580002  36.910000  38.000000  37.029999  11599800  37.029999
# 2022-06-14  38.869999  37.189999  37.950001  37.220001  13408100  37.220001
# 2022-06-15  38.509998  37.250000  37.500000  37.990002  14434683  37.990002

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,80],figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## xlimit and y limit and coloring
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,90],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-06-16', '2017-06-19', '2017-06-20', '2017-06-21',
#                '2017-06-22', '2017-06-23', '2017-06-26', '2017-06-27',
#                '2017-06-28', '2017-06-29',
#                ...
#                '2022-06-02', '2022-06-03', '2022-06-06', '2022-06-07',
#                '2022-06-08', '2022-06-09', '2022-06-10', '2022-06-13',
#                '2022-06-14', '2022-06-15'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
index=df_tesla.loc['2020-01-01':'2021-09-01'].index
share_open=df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02    32.310001
# 2020-01-03    31.709999
# 2020-01-06    31.230000
# 2020-01-07    31.799999
# 2020-01-08    32.349998
#                 ...
# 2021-08-26    63.959999
# 2021-08-27    62.720001
# 2021-08-30    63.700001
# 2021-08-31    64.519997
# 2021-09-01    64.650002
# Name: Open, Length: 421, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-19', '2021-08-20', '2021-08-23', '2021-08-24',
#                '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-30',
#                '2021-08-31', '2021-09-01'],
#               dtype='datetime64[ns]', name='Date', length=421, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
## Datetime Index

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   High       1259 non-null   float64
#  2   Low        1259 non-null   float64
#  3   Open       1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Volume     1259 non-null   int64
#  6   Adj Close  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.0 KB

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2017-06-16  16.809999  16.549999  16.750000  16.670000   9939400  16.670000
# 2017-06-19  17.080000  16.750000  16.770000  17.059999  11318900  17.059999
# 2017-06-20  17.150000  16.840000  17.150000  16.910000   8524600  16.910000
# 2017-06-21  18.040001  17.110001  17.110001  17.780001  23734800  17.780001
# 2017-06-22  18.379999  17.660000  17.850000  18.150000  20734500  18.150000

# %%
## datetime
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 6, 15, 17, 51, 16, 308017)

# %%
date=datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %% [markdown]
# ## Time Resampling

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2017-06-16  16.809999  16.549999  16.750000  16.670000   9939400  16.670000
# 2017-06-19  17.080000  16.750000  16.770000  17.059999  11318900  17.059999
# 2017-06-20  17.150000  16.840000  17.150000  16.910000   8524600  16.910000
# 2017-06-21  18.040001  17.110001  17.110001  17.780001  23734800  17.780001
# 2017-06-22  18.379999  17.660000  17.850000  18.150000  20734500  18.150000

# %%
df_tesla.resample(rule='A').min()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close
# Date
# 2017-12-31  16.059999  15.670000  15.670000  15.750000  5551500  15.750000
# 2018-12-31  22.680000  22.040001  22.389999  22.160000  5813900  22.160000
# 2019-12-31  28.990000  27.870001  28.260000  27.990000  4290500  27.990000
# 2020-12-31  23.490000  20.000000  22.110001  22.000000  3661100  22.000000
# 2021-12-31  43.099998  41.009998  42.110001  42.070000  5060100  42.070000
# 2022-12-31  33.459999  31.299999  31.299999  32.419998  7970300  32.419998

# %%
df_tesla.resample(rule='A').max()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2017-12-31  25.559999  24.700001  25.440001  25.200001  112277600  25.200001
# 2018-12-31  47.790001  45.639999  46.740002  46.759998  162434400  46.759998
# 2019-12-31  45.860001  44.560001  45.599998  45.419998  105112500  45.419998
# 2020-12-31  56.110001  54.369999  55.340000  55.869999  109654700  55.869999
# 2021-12-31  80.750000  76.050003  78.360001  77.629997   88378800  77.629997
# 2022-12-31  54.570000  50.560001  53.849998  51.700001  268465400  51.700001

# %%
##year end frequency
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##quaterly start frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
##Business End Frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='BA').max()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2017-12-29  25.559999  24.700001  25.440001  25.200001  112277600  25.200001
# 2018-12-31  47.790001  45.639999  46.740002  46.759998  162434400  46.759998
# 2019-12-31  45.860001  44.560001  45.599998  45.419998  105112500  45.419998
# 2020-12-31  56.110001  54.369999  55.340000  55.869999  109654700  55.869999
# 2021-12-31  80.750000  76.050003  78.360001  77.629997   88378800  77.629997
# 2022-12-30  54.570000  50.560001  53.849998  51.700001  268465400  51.700001

# %%
df_tesla.resample(rule='BQS').max()
# Out:
#                    High          Low         Open        Close       Volume  \
# Date
# 2017-01-02    56.400002    55.442001    55.745998    55.660000   57304000.0
size=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ##Assignment
# ##news
# 1. Read the Microsoft Data using Pandas Data reader
# 2. Get the maximum price of the share from 2017 to 2022
# 3. Which is the date of the highest price of the stock?
# 4. Which is the date of the lowest price of the stock?

# %%
df_mic = pdr.get_data_yahoo('MSFT')

# %%
df_mic.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-06-09  272.709991  264.630005  267.779999  264.790009  26439700.0
# 2022-06-10  260.579987  252.529999  260.579987  252.990005  31422800.0
# 2022-06-13  249.020004  241.529999  245.110001  242.259995  46135800.0
# 2022-06-14  245.740005  241.509995  243.860001  244.490005  28651500.0
# 2022-06-15  255.300003  246.419998  248.309998  251.759995  33073500.0
#
#              Adj Close
# Date
# 2022-06-09  264.790009
# 2022-06-10  252.990005
# 2022-06-13  242.259995
# 2022-06-14  244.490005
# 2022-06-15  251.759995

# %%
df_mic.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-06-16  70.029999  69.220001  69.730003  70.000000  48345100.0  65.565773
# 2017-06-19  70.940002  70.349998  70.500000  70.870003  23798300.0  66.380669
# 2017-06-20  70.870003  69.870003  70.820000  69.910004  21512200.0  65.481468
# 2017-06-21  70.620003  69.940002  70.209999  70.269997  19891100.0  65.818672
# 2017-06-22  70.589996  69.709999  70.540001  70.260002  22965700.0  65.809311

# %%
df_mic['High'].max()
# Out:
# 349.6700134277344

# %%
df_mic['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_mic.resample(rule='A').max()['High']
# Out:
# Date
# 2017-12-31     87.500000
# 2018-12-31    116.180000
# 2019-12-31    159.550003
# 2020-12-31    232.860001
# 2021-12-31    349.670013
# 2022-12-31    338.000000
# Freq: A-DEC, Name: High, dtype: float64

# %%
df_mic.resample(rule='A').min()['Low']
# Out:
# Date
# 2017-12-31     68.019997
# 2018-12-31     83.830002
# 2019-12-31     97.199997
# 2020-12-31    132.520004
# 2021-12-31    211.940002
# 2022-12-31    241.509995
# Freq: A-DEC, Name: Low, dtype: float64

# %% [markdown]
# ## SIMPLE MOVING AVERAGE

# %%
df_tesla['Open'].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:10 day Rolling']=df_tesla['Open'].rolling(window=10,min_periods=1).mean()

# %%
df_tesla[['Open','Open:10 day Rolling']].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:20 day Rolling']=df_tesla['Open'].rolling(window=20,min_periods=1).mean()
df_tesla['Open:30 day Rolling']=df_tesla['Open'].rolling(window=30,min_periods=1).mean()
df_tesla['Open:50 day Rolling']=df_tesla['Open'].rolling(window=50,min_periods=1).mean()

# %%
df_tesla[['Open','Open:20 day Rolling','Open:30 day Rolling','Open:50 day Rolling']].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#EXPANDING
#CMA
df_tesla['Open'].expanding().mean().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#EWMA
#sMOOTHING FACTOR - 0.1
df_tesla['EMA_0.1']= df_tesla['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1']].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['EMA_0.3']= df_tesla['Open'].ewm(alpha=0.3,adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1','EMA_0.3']].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['EMA_5days']= df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open','EMA_0.1','EMA_5days']].plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>
